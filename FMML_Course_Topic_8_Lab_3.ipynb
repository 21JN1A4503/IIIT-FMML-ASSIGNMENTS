# %% [markdown]
# <a href="https://colab.research.google.com/github/21JN1A4503/IIIT-FMML-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 10:04:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  92.7MB/s    in 0.7s
#
# 2024-03-27 10:04:44 (92.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15421   1412.7415v2  Sign language, which is a medium of communicat...    cs
# 12128  1709.00537v2  We propose a communicationally and computation...  stat
# 30796  1801.04187v1  Salient object detection is a fundamental prob...    cs
# 24664   1410.3080v1  A Bayesian compressive sensing framework is de...    cs
# 27331  1703.03196v1  Image segmentation is the process of partition...    cs
# ...             ...                                                ...   ...
# 24458   1312.7085v1  To effectively retrieve objects from large cor...    cs
# 39601  1610.01502v2  We use tools from geometric statistics to anal...    cs
# 24049  1612.03557v1  Visual attention plays an important role to un...    cs
# 8856   1605.00122v1  Novelty detection in news events has long been...    cs
# 17602  1712.08439v1  Distributional semantics models derive word sp...    cs
#
#                                                    title  year  \
# 15421  A prototype Malayalam to Sign Language Automat...  2014
# 12128  Communication-efficient Algorithm for Distribu...  2017
# 30796  MSDNN: Multi-Scale Deep Neural Network for Sal...  2018
# 24664  Tree-Structure Bayesian Compressive Sensing fo...  2014
# 27331  Prior-based Hierarchical Segmentation Highligh...  2017
# ...                                                  ...   ...
# 24458  Finding More Relevance: Propagating Similarity...  2013
# 39601  Template shape estimation: correcting an asymp...  2016
# 24049   Text-guided Attention Model for Image Captioning  2016
# 8856   An Improved System for Sentence-level Novelty ...  2016
# 17602  Novel Ranking-Based Lexical Similarity Measure...  2017
#
#                                                 keywords
# 15421  [communication, communication, prototype, mala...
# 12128  [communicationally, computationally, efficient...
# 30796  [detection, fundamental, attentions, extractio...
# 24664  [compressive, framework, developed, reconstruc...
# 27331  [segmentation, partitioning, meaningful, accor...
# ...                                                  ...
# 24458  [effectively, challenge, propagates, similarit...
# 39601  [geometric, statistics, estimation, procedure,...
# 24049  [attention, important, understand, demonstrate...
# 8856   [detection, difficult, performed, particularly...
# 17602  [distributional, semantics, linguistic, corres...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15421    [communication, communication, prototype, mala...
# 12128    [communicationally, computationally, efficient...
# 30796    [detection, fundamental, attentions, extractio...
# 24664    [compressive, framework, developed, reconstruc...
# 27331    [segmentation, partitioning, meaningful, accor...
#                                ...
# 26832    [semantically, plausible, impacting, fundament...
# 4552     [reinforcement, approximation, approximating, ...
# 34277    [commentwatcher, analyzing, discussions, const...
# 11278    [separation, technique, multichannel, applicat...
# 5418     [framework, representations, statistical, tech...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8777 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="35863ae9-e3bd-4c94-abb0-bfece0372790" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35863ae9-e3bd-4c94-abb0-bfece0372790")) {                    Plotly.newPlot(                        "35863ae9-e3bd-4c94-abb0-bfece0372790",                        [{"x":["translator","generated","animation","educational","communication","translation","information","automatic","malayalam","prototype","hospitals","corresponding","generates","performance","simulated","estimation","computationally","decreases","iteration","algorithm","centralized","dimensional","dimension","distributed","minimization","assumptions","extensive","efficient","comparable","experiments","procedure","truncation","exponentially","theoretically","regularized","detection","representation","deconvolutional","extensively","extraction","convolution","recurrent","evaluated","fundamental","approaches","outperforms","significantly","attentions","convolutional","investigate","benchmark","structure","compressive","exploiting","inversion","measurement","transformation","coefficients","reconstruct","framework","developed","reconstruction","applications","important","efficiency","preserving","versatile","highlighting","hierarchical","emergence","different","according","segmentation","partitioning","emphasizes","presented","meaningful","structures","versatility","illustrate","automated","collection","cognitive","interpretability","outperformed","conditions","considerable","methodology","techniques","resulting","digitizing","currently","substantially","screening","clinicians","precision","indicated","interpretable","inexpensive","classification","regularizer","discriminability","improving","regularizations","significant","established","compositional","marginalized","generalization","integrand","sequential","investigation","understood","demonstrate","magnitude","distribution","importance","minimises","tempering","determined","considered","integration","practical","empirical","reduction","sensitive","smoothness","quadrature","numerical","artificial","summarization","obstacles","attracted","advancements","statistical","investigated","predicted","surrogate","uncertain","behaviors","unexpected","situations","objective","introducing","simulations","importantly","confidence","functions","parameters","generation","addresses","environment","investigating","reliability","optimization","situation","consistently","technique","repeatmulti","satisfies","truncated","interesting","probability","completion","summarize","multiplicative","observation","covariance","frobenius","incoherence","approximation","observing","performing","gradients","particularly","classifiers","approached","predictions","systematic","assigning","available","predictors","visualization","simultaneously","deconvolution","indicative","detecting","relevance","boundaries","annotations","following","algorithms","conventional","propagation","conditional","introduce","conditioning","processes","maximizing","selection"],"y":[5,172,4,9,56,123,711,172,4,29,2,145,52,889,50,200,85,13,44,799,5,183,67,88,62,72,164,387,93,599,112,4,26,40,38,361,366,6,27,121,49,143,143,79,422,255,254,8,408,146,212,324,14,86,11,39,53,40,24,535,194,87,435,368,144,50,12,13,94,16,774,89,207,18,2,192,64,134,3,70,102,64,47,23,17,146,44,69,375,157,2,59,38,10,10,68,8,33,6,521,12,4,117,2,243,54,23,4,111,0,60,45,36,536,66,203,94,1,2,41,127,55,145,150,103,56,11,0,78,135,25,9,22,9,152,43,47,17,27,33,5,55,181,61,44,27,44,214,233,151,60,125,15,24,302,29,41,232,0,15,11,74,185,27,15,15,63,21,3,5,103,22,92,34,91,120,6,84,38,10,312,10,29,142,12,5,70,29,39,64,81,589,107,97,101,340,16,95,33,131],"type":"bar"},{"x":["translator","generated","animation","educational","commun ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Perfect</span> <span style=''>Derived</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Propagators</span> <br/><br/><span style=''>When</span> <span style='background-color:rgba(0, 255, 0, 0.4358974358974359);'>implementing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>propagator</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.43661971830985913);'>constraint</span> <span style=''>one</span> <span style=''>must</span> <span style=''>decide</span> <span style=''>about</span> <span style=''>variants</span> <span style=''>When</span> <span style='background-color:rgba(0, 255, 0, 0.4358974358974359);'>implementing</span> <span style=''>min</span> <span style=''>should</span> <span style=''>one</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>max</span> <span style=''>Should</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695654);'>equations</span> <span style=''>both</span> <span style=''>with</span> <span style=''>and</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style='background-color:rgba(0, 255, 0, 0.43661971830985913);'>Constraint</span> <span style=''>variants</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ubiquitous</span> <span style='background-color:rgba(0, 255, 0, 0.4358974358974359);'>implementing</span> <span style=''>them</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>considerable</span> <span style=''>(if</span> <span style=''>not</span> <span style=''>prohibitive)</span> <span style=''>effort</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreases</span> <span style=''>maintainability</span> <span style=''>but</span> <span style=''>will</span> <span style=''>deliver</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>shows</span> <span style=''>how</span> <span style=''>to</span> <span style=''>use</span> <span style=''>variable</span> <span style=''>views</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>for</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style='background-color:rgba(0, 255, 0, 0.5813953488372092);'>architecture</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>perfect</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>propagator</span> <span style=''>variants</span> <span style=''>A</span> <span style=''>model</span> <span style=''>for</span> <span style=''>views</span> <span style=''>and</span> <span style=''>derived</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propagators</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>Derived</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propagators</span> <span style=''>are</span> <span style=''>proved</span> <span style=''>to</span> <span style=''>be</span> <span style=''>indeed</span> <span style=''>perfect</span> <span style=''>in</span> <span style=''>that</span> <span style=''>they</span> <span style=''>inherit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>to</span> <span style=''>multi</span> <span style=''>label</span> <span style=''>learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>called</span> <span style=''>H2PC</span> <span style=''>It</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructs</span> <span style=''>the</span> <span style=''>skeleton</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style=''>and</span> <span style=''>then</span> <span style=''>performs</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>scoring</span> <span style=''>greedy</span> <span style=''>hill</span> <span style=''>climbing</span> <span style=''>search</span> <span style=''>to</span> <span style=''>orient</span> <span style=''>the</span> <span style=''>edges</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>based</span> <span style=''>subroutines</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>around</span> <span style=''>a</span> <span style=''>target</span> <span style=''>variable</span> <span style=''>We</span> <span style=''>conduct</span> <span style=''>two</span> <span style=''>series</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>of</span> <span style=''>H2PC</span> <span style=''>against</span> <span style=''>Max</span> <span style=''>Min</span> <span style=''>Hill</span> <span style=''>Climbing</span> <span style=''>(MMHC)</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style=''>the</span> <span style=''>most</span> <span style=''>powerful</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>First</span> <span style=''>we</span> <span style=''>use</span> <span style=''>eight</span> <span style=''>well</span> <span style=''>known</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmarks</span> <span style=''>with</span> <span style=''>various</span> <span style=''>data</span> <span style=''>sizes</span> <span style=''>to</span> <span style=''>assess</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>Learning</span> <span style=''>Rate</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.661290322580645);'>Covariance</span> <span style=''>Matrix</span> <span style=''>Based</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>Preconditioning</span> <span style=''>for</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Adaptive</span> <span style=''>learning</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>such</span> <span style=''>as</span> <span style=''>RMSProp</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>for</span> <span style=''>training</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>RMSProp</span> <span style=''>offers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>training</span> <span style=''>since</span> <span style=''>it</span> <span style=''>uses</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>Hessian</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>preconditioning</span> <span style=''>However</span> <span style=''>since</span> <span style=''>the</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <span style=''>include</span> <span style=''>noise</span> <span style=''>caused</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.37305699481865284);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.34810126582278483);'>approximation</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inaccurate</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>adaptive</span> <span style=''>learning</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>SDProp</span> <span style=''>Its</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.35294117647058826);'>effective</span> <span style=''>handling</span> <span style=''>of</span> <span style=''>the</span> <span style=''>noise</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>preconditioning</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.661290322580645);'>covariance</span> <span style=''>matrix</span> <span style=''>For</span> <span style=''>various</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.35294117647058826);'>effective</span> <span style=''>than</span> <span style=''>RMSProp</span> <span style=''>and</span> <span style=''>its</span> <span style=''>variant</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalised</span> <span style=''>Reichenbachian</span> <span style=''>Common</span> <span style=''>Cause</span> <span style=''>Systems</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style=''>the</span> <span style=''>common</span> <span style=''>cause</span> <span style=''>claims</span> <span style=''>that</span> <span style=''>if</span> <span style=''>an</span> <span style=''>improbable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coincidence</span> <span style=''>has</span> <span style=''>occurred</span> <span style=''>there</span> <span style=''>must</span> <span style=''>exist</span> <span style=''>a</span> <span style=''>common</span> <span style=''>cause</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>taken</span> <span style=''>to</span> <span style=''>mean</span> <span style=''>that</span> <span style=''>positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>non</span> <span style=''>causally</span> <span style=''>related</span> <span style=''>events</span> <span style=''>should</span> <span style=''>disappear</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioning</span> <span style=''>on</span> <span style=''>the</span> <span style=''>action</span> <span style=''>of</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>common</span> <span style=''>cause</span> <span style=''>The</span> <span style=''>extended</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>by</span> <span style=''>contrast</span> <span style=''>urges</span> <span style=''>that</span> <span style=''>common</span> <span style=''>causes</span> <span style=''>should</span> <span style=''>be</span> <span style=''>called</span> <span style=''>for</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>explain</span> <span style=''>positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deviations</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>of</span> <span style=''>two</span> <span style=''>events</span> <span style=''>and</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>value</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>The</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>extended</span> <span style=''>reading</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>with</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capturing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneous</span> <span style=''>action</span> <span style=''>of</span> <span style=''>a</span> <span style=''>system</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>common</span> <span style=''>causes</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1307609860664523)
# 	architecture (0.08503036798856735)
# 	experimental (0.13897820650232226)
# 	segmentation (0.07395498392282958)
# 	knowledge (0.1382636655948553)
# 	information (0.2540192926045016)
# 	detection (0.12897463379778493)
# 	different (0.2765273311897106)
# 	recognition (0.1321900678813862)
# 	convolutional (0.1457663451232583)
#
# Some Statistics words are:
# 	variables (0.1329335332333833)
# 	stochastic (0.13243378310844578)
# 	theoretical (0.1584207896051974)
# 	estimation (0.17391304347826086)
# 	algorithm (0.3888055972013993)
# 	statistical (0.16391804097951024)
# 	distribution (0.1854072963518241)
# 	dimensional (0.1904047976011994)
# 	inference (0.20739630184907545)
# 	regression (0.1854072963518241)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="202dcc5e-6582-4b5f-830d-bac8c5d93766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("202dcc5e-6582-4b5f-830d-bac8c5d93766")) {                    Plotly.newPlot(                        "202dcc5e-6582-4b5f-830d-bac8c5d93766",                        [{"x":["translator","generated","animation","educational","communication","translation","information","automatic","malayalam","prototype","hospitals","corresponding","generates","performance","simulated","estimation","computationally","decreases","iteration","algorithm","centralized","dimensional","dimension","distributed","minimization","assumptions","extensive","efficient","comparable","experiments","procedure","truncation","exponentially","theoretically","regularized","detection","representation","deconvolutional","extensively","extraction","convolution","recurrent","evaluated","fundamental","approaches","outperforms","significantly","attentions","convolutional","investigate","benchmark","structure","compressive","exploiting","inversion","measurement","transformation","coefficients","reconstruct","framework","developed","reconstruction","applications","important","efficiency","preserving","versatile","highlighting","hierarchical","emergence","different","according","segmentation","partitioning","emphasizes","presented","meaningful","structures","versatility","illustrate","automated","collection","cognitive","interpretability","outperformed","conditions","considerable","methodology","techniques","resulting","digitizing","currently","substantially","screening","clinicians","precision","indicated","interpretable","inexpensive","classification","regularizer","discriminability","improving","regularizations","significant","established","compositional","marginalized","generalization","integrand","sequential","investigation","understood","demonstrate","magnitude","distribution","importance","minimises","tempering","determined","considered","integration","practical","empirical","reduction","sensitive","smoothness","quadrature","numerical","artificial","summarization","obstacles","attracted","advancements","statistical","investigated","predicted","surrogate","uncertain","behaviors","unexpected","situations","objective","introducing","simulations","importantly","confidence","functions","parameters","generation","addresses","environment","investigating","reliability","optimization","situation","consistently","technique","repeatmulti","satisfies","truncated","interesting","probability","completion","summarize","multiplicative","observation","covariance","frobenius","incoherence","approximation","observing","performing","gradients","particularly","classifiers","approached","predictions","systematic","assigning","available","predictors","visualization","simultaneously","deconvolution","indicative","detecting","relevance","boundaries","annotations","following","algorithms","conventional","propagation","conditional","introduce","conditioning","processes","maximizing","selection","variables","challenge","effectiveness","notoriously","complexity","providing","cumulative","guarantees","observations","determining","contemporary","traditional","additionally","bidirectional","predicting","especially","advantage","architecture","phenomenon","knowledge","attention","decreasing","prediction","embedding","popularity","combining","universal","combination","resources","evaluations","transcribed","adaptation","collected","evaluation","performed","classifier","languages","conclusions","characterize","operators","considering","expectation","formalisms","characterization","relations","consequence","application","representations","preferential","extending","gardenfors","inference","introduced","makinsons" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	integrand
# 	quadrature
# 	repeatmulti
# 	thermostats
# 	thermostat
# 	searchlight
# 	individualized
# 	jackknife
# 	reparametrization
# 	reparametrizations
# 	hermitian
# 	regressionclassification
# 	omnipresent
# 	ancestral
# 	logarithmically
# 	connectome
# 	stragglers
# 	extrapolate
# 	postulate
# 	approachability
# Some words which never appear in Statistics papers:
# 	translator
# 	animation
# 	malayalam
# 	indicative
# 	transcribed
# 	formalisms
# 	gardenfors
# 	makinsons
# 	paragraph
# 	neocortical
# 	formations
# 	arrangements
# 	configured
# 	skeletons
# 	researches
# 	misalignment
# 	reproduction
# 	escherichia
# 	colloquial
# 	forensics

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072385400024579e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
